# %% [markdown]
# <a href="https://colab.research.google.com/github/lc0/deeplearning-playground/blob/master/Altair_image_hover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images_norm = train_images/256
test_images_norm = test_images/256

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images_norm, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5024 - accuracy: 0.8234
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3744 - accuracy: 0.8658
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3357 - accuracy: 0.8780
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3100 - accuracy: 0.8855
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2944 - accuracy: 0.8913

# %%
loss, accuracy = model.evaluate(test_images_norm, test_labels)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3475 - accuracy: 0.8742
# Test loss: 0.3475441634654999
# Test accuracy: 0.8741999864578247

# %% [markdown]
# ## Visualisation

# %%
sample_images = train_images_norm[:5000].reshape(-1 ,28*28)
sample_labels = train_labels[:5000]

# %%
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# %% [markdown]
# ## PCA + Extract from last layer

# %%
from sklearn.decomposition import PCA

model_features = tf.keras.Model(model.inputs, model.get_layer('dense').output)

# %%
image_features = model_features.predict(sample_images.reshape(-1, 28, 28))

# %%
pca = PCA(n_components=2)

extracted_pca_data = pca.fit_transform(image_features)

# %% [markdown]
# # Altair visualization

# %% [markdown]
# ## Flask server for images

# %%
# !pip install flask_cors
# Out:
# Requirement already satisfied: flask_cors in /usr/local/lib/python3.6/dist-packages (3.0.8)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.6/dist-packages (from flask_cors) (1.1.2)
# Requirement already satisfied: Six in /usr/local/lib/python3.6/dist-packages (from flask_cors) (1.12.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (2.11.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.9->flask_cors) (7.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.9->flask_cors) (1.1.1)

# %% [markdown]
# ### flask-grok
#
# Here I extended a bit to run flask in separate thread

# %%
# !pip install git+https://github.com/lc0/flask-ngrok@thread
# Out:
# Collecting git+https://github.com/lc0/flask-ngrok@thread
#   Cloning https://github.com/lc0/flask-ngrok (to revision thread) to /tmp/pip-req-build-0tqwvtk4
#   Running command git clone -q https://github.com/lc0/flask-ngrok /tmp/pip-req-build-0tqwvtk4
#   Running command git checkout -b thread --track origin/thread
#   Switched to a new branch 'thread'
#   Branch 'thread' set up to track remote branch 'thread' from 'origin'.
# Requirement already satisfied (use --upgrade to upgrade): flask-ngrok==0.0.26 from git+https://github.com/lc0/flask-ngrok@thread in ./flask-ngrok
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.6/dist-packages (from flask-ngrok==0.0.26) (1.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from flask-ngrok==0.0.26) (2.21.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok==0.0.26) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok==0.0.26) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok==0.0.26) (7.1.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok==0.0.26) (2.11.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok==0.0.26) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok==0.0.26) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok==0.0.26) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok==0.0.26) (2020.4.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok==0.0.26) (1.1.1)
# Building wheels for collected packages: flask-ngrok
#   Building wheel for flask-ngrok (setup.py) ... done
#   Created wheel for flask-ngrok: filename=flask_ngrok-0.0.26-cp36-none-any.whl size=6233 sha256=fb626b5f42d66fc0ae7fa572ecafdc652ddeba077e3c6867c3132203a2d37397
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w_wn5okl/wheels/af/00/62/632d10dbddb6224ed6535cb27ae2d9629421362638885cdad1
# Successfully built flask-ngrok

# %%
from flask_ngrok import start_flask_thread
server_thread = None

# %%
import io
from PIL import Image
from flask import Flask, send_file
from flask_cors import CORS


app = Flask(__name__)
CORS(app)

@app.route("/img/<int:image_id>.png")
def image(image_id):
    # convert numpy array to PIL Image
    img = Image.fromarray(sample_images[image_id].reshape(28, 28)*255).convert('RGB')

    # create file-object in memory
    file_object = io.BytesIO()

    # write PNG in file-object
    img.save(file_object, 'PNG')

    # move to beginning of file so `send_file()` it will read from start
    file_object.seek(0)

    return send_file(file_object, mimetype='image/PNG')

# %%
server_thread = start_flask_thread(server_thread, app, port=5555)
# Out:
#  * Running on ['https://77f2a29b.ngrok.io']
# Started a server thread on 0.0.0.0:5555

# %% [markdown]
# ## Altair Grammar

# %%
import altair as alt
import numpy as np
import pandas as pd

# %%
BASE_URL = 'https://77f2a29b.ngrok.io'
dummy_image_ids = [f"{BASE_URL}/img/{image_id}.png" for image_id in range(0, len(sample_labels))]

# %%
dummy_image_ids[:10]
# Out:
# ['https://77f2a29b.ngrok.io/img/0.png',
#  'https://77f2a29b.ngrok.io/img/1.png',
#  'https://77f2a29b.ngrok.io/img/2.png',
#  'https://77f2a29b.ngrok.io/img/3.png',
#  'https://77f2a29b.ngrok.io/img/4.png',
#  'https://77f2a29b.ngrok.io/img/5.png',
#  'https://77f2a29b.ngrok.io/img/6.png',
#  'https://77f2a29b.ngrok.io/img/7.png',
#  'https://77f2a29b.ngrok.io/img/8.png',
#  'https://77f2a29b.ngrok.io/img/9.png']

# %%
def visualize_embeddings_altair(data, labels, dummy_image_ids):
    pca_data_labels = np.vstack((data.T, labels, dummy_image_ids)).T
    df = pd.DataFrame(data=pca_data_labels, columns=['x', 'y', 'label', 'image_id'])

    multi_mouseover = alt.selection_multi(on='mouseover', toggle=True, empty='none')


    base = alt.Chart(df).mark_circle(radius=50).encode(
        x='x:Q',
        y='y:Q',

        color='label:N',
    ).add_selection(
        multi_mouseover
    )

    
    image = alt.Chart(df).mark_image(
    ).encode(
        url='image_id'
    ).transform_filter(
        multi_mouseover
    ).properties(width=100, height=100)
    
    return base | image


visualize_embeddings_altair(extracted_pca_data, sample_labels, dummy_image_ids)
# Out:
# alt.HConcatChart(...)
